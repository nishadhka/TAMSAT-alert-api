# %%
import xarray as xr

#db=xr.open_dataset('/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/tamsat/for_training/outputs/ens_mean_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc')


ens_db='/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/tamsat/for_training/outputs/ensemble_forecast_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc'

db=xr.open_dataset(ens_db)

db
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 92, longitude: 35, latitude: 42, ens_year: 15)
# Coordinates:
#   * time          (time) datetime64[ns] 2022-10-01 2022-10-02 ... 2022-12-31
#   * longitude     (longitude) float32 33.38 33.62 33.88 ... 41.38 41.62 41.88
#   * latitude      (latitude) float32 -4.875 -4.625 -4.375 ... 4.875 5.125 5.375
#   * ens_year      (ens_year) int64 2005 2006 2007 2008 ... 2016 2017 2018 2019
# Data variables:
#     beta_c4grass  (longitude, latitude, time, ens_year) float32 ...

# %%
db['ens_year'].values
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019])

# %%
aa=db['time'][1]

# %%
db['beta_c4grass'].values.shape
# Out:
# (35, 42, 92, 15)

# %%
ncpath='/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/tamsat/for_training/outputs/'

db=xr.open_dataset(f'{ncpath}prob_lower_tercile_OND2022_20221005_33.5_42.0_-4.8_5.5.nc')

db
# Out:
# <xarray.Dataset>
# Dimensions:                        (longitude: 35, latitude: 42)
# Coordinates:
#   * longitude                      (longitude) float32 33.38 33.62 ... 41.88
#   * latitude                       (latitude) float32 -4.875 -4.625 ... 5.375
# Data variables:
#     __xarray_dataarray_variable__  (longitude, latitude) float64 ...

# %%
db=xr.open_dataset(f'{ncpath}percent_anom_OND2022_20221005_33.5_42.0_-4.8_5.5.nc')

db
# Out:
# <xarray.Dataset>
# Dimensions:                        (longitude: 35, latitude: 42)
# Coordinates:
#   * longitude                      (longitude) float32 33.38 33.62 ... 41.88
#   * latitude                       (latitude) float32 -4.875 -4.625 ... 5.375
# Data variables:
#     __xarray_dataarray_variable__  (longitude, latitude) float64 ...

# %%
db=xr.open_dataset(f'{ncpath}ens_sd_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc')

db
# Out:
# <xarray.Dataset>
# Dimensions:                        (longitude: 35, latitude: 42)
# Coordinates:
#   * longitude                      (longitude) float32 33.38 33.62 ... 41.88
#   * latitude                       (latitude) float32 -4.875 -4.625 ... 5.375
# Data variables:
#     __xarray_dataarray_variable__  (longitude, latitude) float64 ...

# %%
filenames=['prob_lower_tercile_OND2022_20221005_33.5_42.0_-4.8_5.5.nc',
          'percent_anom_OND2022_20221005_33.5_42.0_-4.8_5.5.nc',
          'ens_sd_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc',
          'ens_mean_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc',
          'ensemble_forecast_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc',
          'clim_sd_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc',
          'clim_mean_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc']


for flnm in filenames:
    print(flnm)
    db=xr.open_dataset(f'{ncpath}{flnm}')
    print(db)
# Out:
# prob_lower_tercile_OND2022_20221005_33.5_42.0_-4.8_5.5.nc
# <xarray.Dataset>
# Dimensions:                        (longitude: 35, latitude: 42)
# Coordinates:
#   * longitude                      (longitude) float32 33.38 33.62 ... 41.88
#   * latitude                       (latitude) float32 -4.875 -4.625 ... 5.375
# Data variables:
#     __xarray_dataarray_variable__  (longitude, latitude) float64 ...
# percent_anom_OND2022_20221005_33.5_42.0_-4.8_5.5.nc
# <xarray.Dataset>
# Dimensions:                        (longitude: 35, latitude: 42)
# Coordinates:
#   * longitude                      (longitude) float32 33.38 33.62 ... 41.88
#   * latitude                       (latitude) float32 -4.875 -4.625 ... 5.375
# Data variables:
#     __xarray_dataarray_variable__  (longitude, latitude) float64 ...
# ens_sd_wrsi_OND2022_20221005_33.5_42.0_-4.8_5.5.nc
# <xarray.Dataset>
# Dimensions:                        (longitude: 35, latitude: 42)
# Coordinates:
# ...

# %%
import xarray as xr

wrsi_path='/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/tamsat/tamsat_nceo_da_wb_v1p0p1_20150102.nc'

db=xr.open_dataset(wrsi_path)

db['smcl']
# Out:
# <xarray.DataArray 'smcl' (time: 1, soil: 4, y: 292, x: 278)>
# [324704 values with dtype=float32]
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-02T12:00:00
#     longitude  (y, x) float32 ...
#     latitude   (y, x) float32 ...
# Dimensions without coordinates: soil, y, x
# Attributes:
#     long_name:     Gridbox moisture content of each soil layer
#     units:         kg m-2
#     cell_methods:  time : mean

# %%
db.time
# Out:
# <xarray.DataArray 'time' (time: 444)>
# array(['1983-01-31T00:00:00.000000000', '1983-02-28T00:00:00.000000000',
#        '1983-03-31T00:00:00.000000000', ..., '2019-10-31T00:00:00.000000000',
#        '2019-11-30T00:00:00.000000000', '2019-12-31T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1983-01-31 1983-02-28 ... 2019-12-31

# %%
db.longitude
# Out:
# <xarray.DataArray 'longitude' (y: 292, x: 278)>
# array([[-17.875, -17.625, -17.375, ...,  50.875,  51.125,  51.375],
#        [-17.875, -17.625, -17.375, ...,  50.875,  51.125,  51.375],
#        [-17.875, -17.625, -17.375, ...,  50.875,  51.125,  51.375],
#        ...,
#        [-17.875, -17.625, -17.375, ...,  50.875,  51.125,  51.375],
#        [-17.875, -17.625, -17.375, ...,  50.875,  51.125,  51.375],
#        [-17.875, -17.625, -17.375, ...,  50.875,  51.125,  51.375]],
#       dtype=float32)
# Coordinates:
#     longitude  (y, x) float32 -17.88 -17.62 -17.38 -17.12 ... 50.88 51.12 51.38
#     latitude   (y, x) float32 -35.38 -35.38 -35.38 -35.38 ... 37.38 37.38 37.38
# Dimensions without coordinates: y, x
# Attributes:
#     standard_name:        longitude
#     long_name:            Gridbox longitude
#     units:                degrees
#     _CoordinateAxisType:  Lon

# %%
https://gws-access.jasmin.ac.uk/public/tamsat/tamsat_alert/
    
http://gws-access.jasmin.ac.uk/public/odanceo/soil_moisture/nc//tamsat_nceo_da_wb_v1p0p1_20150103.nc

# %%
import xarray as xr

wrsi_path='/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/tamsat/for_training/forecasts/alert_20221005_ens.daily.nc'

db=xr.open_dataset(wrsi_path)

db
# Out:
# <xarray.Dataset>
# Dimensions:        (ens_year: 15, time: 150, z: 4, latitude: 292, longitude: 278)
# Coordinates:
#   * ens_year       (ens_year) float32 2.005e+03 2.006e+03 ... 2.019e+03
#   * time           (time) datetime64[ns] 2022-10-04 2022-10-05 ... 2023-03-02
#   * z              (z) float32 100.0 250.0 650.0 2e+03
#   * latitude       (latitude) float32 -35.38 -35.12 -34.88 ... 36.88 37.12 37.38
#   * longitude      (longitude) float32 -17.88 -17.62 -17.38 ... 51.12 51.38
# Data variables:
#     pfc_forc       (ens_year, time, z, latitude, longitude) float32 ...
#     smcl           (ens_year, time, z, latitude, longitude) float32 ...
#     beta_c4grass   (ens_year, time, latitude, longitude) float32 ...
#     smc_avail_top  (ens_year, time, latitude, longitude) float32 ...

# %%
db['beta_c4grass']
# Out:
# <xarray.DataArray 'beta_c4grass' (ens_year: 15, time: 150, latitude: 292, longitude: 278)>
# [182646000 values with dtype=float32]
# Coordinates:
#   * ens_year   (ens_year) float32 2.005e+03 2.006e+03 ... 2.018e+03 2.019e+03
#   * time       (time) datetime64[ns] 2022-10-04 2022-10-05 ... 2023-03-02
#   * latitude   (latitude) float32 -35.38 -35.12 -34.88 ... 36.88 37.12 37.38
#   * longitude  (longitude) float32 -17.88 -17.62 -17.38 ... 50.88 51.12 51.38
# Attributes:
#     long_name:  Gridbox soil moisture availabilty factor (beta) for C4 grasses
#     units:      1

# %%
import xarray as xr

wrsi_path='/home/bulbul/Documents/07-2022/impact_weather_icpac/lab/tamsat/for_training/beta_hist.nc'

db=xr.open_dataset(wrsi_path)

db['time']
# Out:
# <xarray.DataArray 'time' (time: 5478)>
# array(['2003-01-01T00:00:00.000000000', '2003-01-02T00:00:00.000000000',
#        '2003-01-03T00:00:00.000000000', ..., '2017-12-28T00:00:00.000000000',
#        '2017-12-29T00:00:00.000000000', '2017-12-30T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2003-01-01 2003-01-02 ... 2017-12-30

# %%
python filepath forecast_date poi_start poi_end weight_up weight_mid weight_low roi lon_min lon_max
lat_min lat_max


python T-A_API.py 20221005 20221001 20221231 0.15 0.30 0.55 region 33.5 42.0 -4.8 5.5



python OC_overlay_shape.py 20221005 20221001 20221231 /home/bulbul/Documents/07-2022/impact_weather_icpac/lab/tamsat/for_training/practicals/validation_practical/validation_practical/GIS/KEN_adm2.shp 33.5 42.0 -4.8 5.5
